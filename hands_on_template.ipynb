# %% [markdown]
# ## Hands-On: Classification - Crop Recommendation Dataset
#
# https://www.kaggle.com/datasets/abdulrahmanksaeed/agricultural-crop-and-disease-synthetic-dataset
#
# *this is a synthetic dataset based on India settings. For developing a real application, we would need to construct a similar dataset using historical data and specialist's takes*

# %% [markdown]
# **Columns:**
#
# - Soil_Type - type or classification of the soil
# - Temperature_C - temperature in degrees Celsius
# - Rainfall_mm - rainfall amount in millimeters
# - Humidity_pct - humidity percentage in the air
# - Nitrogen_kg_ha - nitrogen content in the soil, measured in kilograms per hectare
# - Phosphorus_kg_ha - phosphorus content in the soil, measured in kilograms per hectare
# - Potassium_kg_ha - potassium content in the soil, measured in kilograms per hectare
# - pH - acidity or alkalinity level of the soil
# - Crop_History - crop planted in the previous cultivation cycle
#
# **Target:**
#
# - Recommended_Crop - crop recommended for the current soil and environmental conditions

# %%
# import the data and look at its structure

# %%
# check for null values and duplicates. Clean if necessary.

# %%
# do eda if you like (important in general, but not required for this activity)

# %%
# do ordinal encoding for the categorical values (too many values for one hot encoding) and for the Target

# %%
# Create two variables, one of features (X) and the other one the labels (targets) (y)

# %%
# Split in train test and validation.

# %%
# Use the standard scaler before training the model. Remember that we need to fit only on train set!

# %%
# Choose two different classification models, train and evaluate them using classification report

# %%
# Choose, based on the metrics, the best model
